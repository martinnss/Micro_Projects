# %%
import pandas as pd
from sklearn.model_selection import train_test_split

data=pd.read_csv(r"G:\Mi unidad\Universidad\Uni\Data science\Heavy Datasets\candy-data.csv")
data
# Out:
#                 competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 0                    100 Grand          1       0        1               0
# 1                 3 Musketeers          1       0        0               0
# 2                     One dime          0       0        0               0
# 3                  One quarter          0       0        0               0
# 4                    Air Heads          0       1        0               0
# ..                         ...        ...     ...      ...             ...
# 80                   Twizzlers          0       1        0               0
# 81                    Warheads          0       1        0               0
# 82        WelchÕs Fruit Snacks          0       1        0               0
# 83  WertherÕs Original Caramel          0       0        1               0
# 84                    Whoppers          1       0        0               0
#
#     nougat  crispedricewafer  hard  bar  pluribus  sugarpercent  pricepercent  \
# 0        0                 1     0    1         0         0.732         0.860
# 1        1                 0     0    1         0         0.604         0.511
# 2        0                 0     0    0         0         0.011         0.116
# 3        0                 0     0    0         0         0.011         0.511
# 4        0                 0     0    0         0         0.906         0.511
# ..     ...               ...   ...  ...       ...           ...           ...
# 80       0                 0     0    0         0         0.220         0.116
# 81       0                 0     1    0         0         0.093         0.116
# 82       0                 0     0    0         1         0.313         0.313
# 83       0                 0     1    0         0         0.186         0.267
# 84       0                 1     0    0         1         0.872         0.848
#
#     winpercent
# 0    66.971725
# 1    67.602936
# 2    32.261086
# 3    46.116505
# 4    52.341465
# ..         ...
# 80   45.466282
# 81   39.011898
# 82   44.375519
# 83   41.904308
# 84   49.524113
#
# [85 rows x 13 columns]

# %%
X_train,X_test,y_train,y_test= train_test_split(data, test_size=0.2,random_state=123)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24952/987648198.py in <module>
# ----> 1 X_train,X_test,y_train,y_test= train_test_split(data, test_size=0.2,random_state=123)
#
# ValueError: not enough values to unpack (expected 4, got 2)

# %% [markdown]
# # VER LOS PRIMEROS CAPITULOS
